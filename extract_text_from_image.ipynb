# %% [markdown]
# # Pablo Calatayud

# %% [markdown]
# # Extracting Text from Image

# %% [markdown]
# ## Table of Contents
# * [0. Loading Image ](#chapter0)
# * [1. Displaying Image ](#chapter1)
# * [2. Calling Function ](#chapter2)
# * [3. Displaying Text Extracted ](#chapter3)

# %% [markdown]
# # 0. Loading Image  <a class="anchor" id="chapter0"></a>

# %%
path_to_image = 'example.PNG'

# %% [markdown]
# # 1. Displaying Image  <a class="anchor" id="chapter1"></a>

# %%
from IPython.display import Image
Image(filename=path_to_image)

# %% [markdown]
# # 2. Calling Function   <a class="anchor" id="chapter2"></a>

# %%
from PIL import Image
from pytesseract import pytesseract

#Define path to tessaract.exe
path_to_tesseract = r'C:\Users\pcalatayud\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'



#Point tessaract_cmd to tessaract.exe
pytesseract.tesseract_cmd = path_to_tesseract

#Open image with PIL
img = Image.open(path_to_image)

#Extract text from image
text = pytesseract.image_to_string(img)

# %% [markdown]
# # 3. Displaying Text Extracted <a class="anchor" id="chapter3"></a>

# %%
print(text)
# Out:
# Cryptofinance. Taking
# stock of the US crypto
# crackdown
